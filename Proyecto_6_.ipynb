# %% [markdown]
# Claudia Mayerly Garzon y Oscar David Fonseca

# %%
import pandas as pd

# %%
imports=pd.read_excel("/content/OO.xlsx")

# %%
imports
# Out:
#   Exporters+A15:N28A15:N26A1A15:U33  Imported value in 2001  \
# 0          United States of America                 4442775
# 1                             China                  475405
# 2                            Mexico                  596168
# 3                            Brazil                  582060
# 4                           Germany                  560090
#
#    Imported value in 2002  Imported value in 2003  Imported value in 2004  \
# 0                 4051198                 4112710                 4806760
# 1                  532847                  688673                 1244730
# 2                  677990                  744375                  935642
# 3                  642840                  769003                 1352172
# 4                  508304                  611672                  686601
#
#    Imported value in 2005  Imported value in 2006  Imported value in 2007  \
# 0                 6033241                 6960605                 8631115
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly
import re

# %%
lista_imp = [re.findall('\d+',i)[0] for i in imports.columns[1:] if len(re.findall('\d+',i)[0])>0]
lista_imp.insert(0, 'paises')

# %%
imports.columns = lista_imp

# %%
imports
# Out:
#                      paises     2001     2002     2003     2004     2005  \
# 0  United States of America  4442775  4051198  4112710  4806760  6033241
# 1                     China   475405   532847   688673  1244730  1616821
# 2                    Mexico   596168   677990   744375   935642  1757068
# 3                    Brazil   582060   642840   769003  1352172  1383387
# 4                   Germany   560090   508304   611672   686601   773661
#
#       2006     2007      2008     2009  ...      2011      2012      2013  \
# 0  6960605  8631115  11583019  9505791  ...  13663338  14140116  16428423
# 1  2219273  3326574   4548798  3715170  ...   8176440   9564690  10362788
# 2  2290571  3072565   3125980  2297888  ...   6059027   6362176   5495958
# 3  1884885  2393940   2328416  2146578  ...   2740248   2795908   2590480
# 4   933215  1204874   1557401  1338394  ...   2215150   2239577   2206909
#
#        2014      2015      2016      2017      2018      2019      2020
# ...

# %%
imports.columns
data = imports.sort_values(by="2020",ascending=False).iloc[:,:]

# %%
basededatosimports=imports.set_index("paises")

# %%
basededatosimports
# Out:
#                              2001     2002     2003     2004     2005  \
# paises
# United States of America  4442775  4051198  4112710  4806760  6033241
# China                      475405   532847   688673  1244730  1616821
# Mexico                     596168   677990   744375   935642  1757068
# Brazil                     582060   642840   769003  1352172  1383387
# Germany                    560090   508304   611672   686601   773661
#
#                              2006     2007      2008     2009      2010  \
# paises
# United States of America  6960605  8631115  11583019  9505791  10531813
# China                     2219273  3326574   4548798  3715170   5477428
# Mexico                    2290571  3072565   3125980  2297888   3856674
# Brazil                    1884885  2393940   2328416  2146578   2369637
# Germany                    933215  1204874   1557401  1338394   1657634
#
#                               2011      2012      2013      2014      2015  \
# paises
# ...

# %% [markdown]
# #Exports

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(basededatosexportaciones, cmap='cool')

# %%
balance=pd.read_excel("/content/balanza.xlsx")

# %%
basededatosbalanca=balance.set_index("paises")

# %%
basededatosbalance
# Out:
#                             2001     2002     2003     2004     2005     2006  \
# paises
# United States of America  901758  1277272  2047535  2235441  2818390  2987625
# China                    -455498  -505022  -606469 -1107226 -1380132 -1766853
# Panama                    206416   173493   148952   187830   201614   165341
# Ecuador                   381703   444360   369299   630582   795407   540147
# Brazil                   -415356  -535017  -676155 -1210984 -1242039 -1694184
#
#                              2007     2008     2009     2010     2011  \
# paises
# United States of America  1978052  2705814  3617675  6611464  8285197
# China                    -2541816 -4105845 -2765444 -3510804 -6187379
# Panama                     107232   162722   149223   756267  1833931
# Ecuador                    543244   689946   562767   989599   842746
# Brazil                   -1922574 -1679475 -1569942 -1329374 -1369940
#
# ...

# %% [markdown]
# #Imports

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(basededatosimportaciones, cmap='jet')

# %%
exports=pd.read_excel("/content/export.xlsx")

# %%
basededatosexports=exports.set_index("paises")

# %%
basededatosexports
# Out:
#                              2001     2002     2003     2004     2005  \
# paises
# United States of America  5344533  5328470  6160245  7042201  8851631
# China                       19907    27825    82204   137504   236689
# Panama                     265163   214697   170524   216490   264140
# Ecuador                    699929   811559   778966  1010665  1324408
# Brazil                     166704   107823    92848   141188   141348
#
#                              2006      2007      2008      2009      2010  \
# paises
# United States of America  9948230  10609167  14288833  13123466  17143277
# China                      452420    784758    442953    949726   1966624
# Panama                     257484    246322    318980    309589    936345
# Ecuador                   1237076   1276036   1499562   1257334   1824535
# Brazil                     190701    471366    648941    576636   1040263
#
#                               2011      2012      2013      2014      2015  \
# ...

# %% [markdown]
# #Balanza Comercial

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(basededatosbalance, cmap='inferno_r')
